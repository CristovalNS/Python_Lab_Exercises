# %%
# Exercise 1
# Try to do the following:
# • Add a key to inventory called 'pocket'.
# • Set the value of 'pocket' to be a list consisting of the strings 'seashell', 'strange berry', and 'lint'.
# • .sort()the items in the list stored under the 'backpack' key.
# • Then .remove('dagger') from the list of items stored under the 'backpack' key.
# • Add 50 to the number stored under the 'gold' key.

inventory = {
    'gold': 500,
    'pouch': ['flint', 'twine', 'gemstone'],
    'backpack': ['xylophone', 'dagger', 'bedroll', 'bread loaf']
    }

print(f"Original dictionary -> {inventory}")

inventory["pocket"] = ["seashell", "strange berry", "lint"]
inventory["backpack"].sort()
inventory["backpack"].remove("dagger")
inventory["gold"] += 50

print(f"New dictionary -> {inventory}")
# Out:
# Original dictionary -> {'gold': 500, 'pouch': ['flint', 'twine', 'gemstone'], 'backpack': ['xylophone', 'dagger', 'bedroll', 'bread loaf']}
# New dictionary -> {'gold': 550, 'pouch': ['flint', 'twine', 'gemstone'], 'backpack': ['bedroll', 'bread loaf', 'xylophone'], 'pocket': ['seashell', 'strange berry', 'lint']}

# %%
# Exercise 2
# o Create a variable called total and set it to zero.
# o Loop through the prices dictionaries. For each key in prices, multiply the number in prices by the
# number in stock. Print that value into the console and then add it to total. 
# o Finally, outside your loop, print total.

prices = {
    "banana": 4,
    "apple": 2,
    "orange": 1.5,
    "pear": 3
    }

stock = {
    "banana": 6,
    "apple": 0,
    "orange": 32,
    "pear": 15
    }

total = 0
for value in prices:
    print(value)
    print("Price:", prices[value])
    print("Stock:", stock[value])

    profit = prices[value] * stock[value]
    print("Money from selling entire stock: ", profit)
    print()
    
    total += profit

print("Total profit:", total)
# Out:
# banana
# Price: 4
# Stock: 6
# Money from selling entire stock:  24
#
# apple
# Price: 2
# Stock: 0
# Money from selling entire stock:  0
#
# orange
# Price: 1.5
# Stock: 32
# Money from selling entire stock:  48.0
#
# pear
# Price: 3
# Stock: 15
# Money from selling entire stock:  45
#
# Total profit: 117.0

# %%
# Exercise 3

my_list = ["banana", "orange", "apple", "banana", "pear", "plum", "banana"]

stock = {
    "banana": 6,
    "apple": 0,
    "orange": 32,
    "pear": 15
    }

prices = {
    "banana": 4,
    "apple": 2,
    "orange": 1.5,
    "pear": 3
    }


def compute_bill(food_list):
    total = 0
    for food in food_list:
        if stock.get(food, 0) > 0:
            total += prices.get(food, 0)
            stock[food] -= 1
    return total


print(compute_bill(my_list))
# Out:
# 16.5

# %%
# Exercise 4

# Student Dictionary
eren = {
    "name": "Eren",
    "homework": [90.0,97.0,75.0,92.0],
    "quizzes": [88.0,40.0,94.0],
    "tests": [75.0,90.0]
    }

mikasa = {
    "name": "Mikasa",
    "homework": [100.0, 92.0, 98.0, 100.0],
    "quizzes": [82.0, 83.0, 91.0],
    "tests": [89.0, 97.0]
    }

armin = {
    "name": "Armin",
    "homework": [0.0, 87.0, 75.0, 22.0],
    "quizzes": [0.0, 75.0, 78.0],
    "tests": [100.0, 100.0]
    }

# Student Data
students = ["eren", "mikasa", "armin"]
for x in students:
    print("Student name:", eval(x + "['name']"))
    print("Homework scores:", eval(x + "['homework']"))
    print("Quizzes scores:", eval(x + "['quizzes']"))
    print("Test scores:", eval(x + "['tests']"))
    print()


# Function to return the average
def average(numbers):
    total = 0
    total += float(sum(numbers)) / len(numbers)

    return total


# Function that takes a student dictionary
def get_average(students):
    homework = float(average(eval(x + "['homework']"))) * 0.1
    quizzes = float(average(eval(x + "['quizzes']"))) * 0.3
    tests = float(average(eval(x + "['tests']"))) * 0.6

    return homework + quizzes + tests


# Function to get letter grade
def get_letter_grade(score: float):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

# Test
print("Eren:", get_letter_grade(get_average("eren")))
print("Mikasa:", get_letter_grade(get_average("mikasa")))
print("Armin:", get_letter_grade(get_average("armin")))

# Function for class average results
def get_class_average(students):
    results = []
    for s in students:
        result = get_average(s)
        results.append(result)

    return average(results)

# Print class average results in numbers and letter
print("Class average: {}".format(get_class_average(students)))
print("Class average: {}".format(get_letter_grade(get_class_average(students))))
# Out:
# Student name: Eren
# Homework scores: [90.0, 97.0, 75.0, 92.0]
# Quizzes scores: [88.0, 40.0, 94.0]
# Test scores: [75.0, 90.0]
#
# Student name: Mikasa
# Homework scores: [100.0, 92.0, 98.0, 100.0]
# Quizzes scores: [82.0, 83.0, 91.0]
# Test scores: [89.0, 97.0]
#
# Student name: Armin
# Homework scores: [0.0, 87.0, 75.0, 22.0]
# Quizzes scores: [0.0, 75.0, 78.0]
# Test scores: [100.0, 100.0]
#
# Eren: C
# Mikasa: C
# Armin: C
# Class average: 79.9
# Class average: C
